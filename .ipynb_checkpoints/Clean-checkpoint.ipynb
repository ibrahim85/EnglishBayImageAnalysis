# %%
from scipy.misc import imread
import pandas as pd
import numpy as np
import glob
import re

# %%
# flatten in imread set to true, images loaded as gray scale
row = 0
image_data = pd.DataFrame(columns=("image", "timestamp"))

for path in sorted(glob.glob("./katkam-scaled/*")):
    
    matches = re.search("\d+", path)
    image_data.loc[row] = [imread(path, flatten=True).flatten(), matches.group()]
    
    #image_data.loc[row] = [imread(path, flatten=True).flatten(), matches.group()]
    row += 1

image_data["timestamp"] = pd.to_datetime(image_data["timestamp"])

# %%
# images = np.zeros((5046,192,256), dtype=np.float32)
# matches = np.empty(5046)
# row = 0
# for path in sorted(glob.glob("./katkam-scaled/*")):
#     matches[row] = re.search("\d+", path).group()
#     images[row] = imread(path, flatten=True)
#     row += 1

# %%
#from sklearn.model_selection import train_test_split
# #probably need to split manually so that times match up
# path = 'katkam-scaled/katkam-20160605060000.jpg'
# imread(path, flatten=True).shape
# Out:
# (192, 256)

# %%
# get list of weather data csv files
files = [f for f in glob.glob("./yvr-weather/*")]

# %%
filename = "./yvr-weather/weather-51442-201606.csv"
weather_data = pd.read_csv(filename, sep=',', skiprows=16, parse_dates=[0])

# %%
# data quality <-- look at later? 
weather_data.drop(["Year","Month","Day","Time","Temp Flag", "Dew Point Temp Flag",
                   "Rel Hum Flag", "Wind Dir Flag", "Wind Spd Flag",
                   "Visibility Flag", "Stn Press Flag",
                   "Hmdx Flag", "Wind Chill Flag", "Hmdx", "Wind Chill",
                   "Data Quality"], axis=1, inplace=True)

# %%
weather_data
# Out:
#               Date/Time  Temp (°C)  Dew Point Temp (°C)  Rel Hum (%)  \
# 0   2016-06-01 00:00:00       14.9                 13.8         93.0
# 1   2016-06-01 01:00:00       15.1                 13.8         92.0
# 2   2016-06-01 02:00:00       15.1                 12.8         86.0
# 3   2016-06-01 03:00:00       14.8                 11.0         78.0
# 4   2016-06-01 04:00:00       14.0                 10.6         80.0
# 5   2016-06-01 05:00:00       13.8                 10.4         80.0
# 6   2016-06-01 06:00:00       14.6                  9.7         72.0
# 7   2016-06-01 07:00:00       16.1                 10.5         69.0
# 8   2016-06-01 08:00:00       16.4                 10.8         69.0
# 9   2016-06-01 09:00:00       17.8                 11.2         65.0
# 10  2016-06-01 10:00:00       18.0                 11.4         65.0
# 11  2016-06-01 11:00:00       19.5                 11.9         61.0
# 12  2016-06-01 12:00:00       20.8                  9.8         49.0
# 13  2016-06-01 13:00:00       20.8                  8.6         45.0
# 14  2016-06-01 14:00:00       18.6                 12.2         66.0
# 15  2016-06-01 15:00:00       16.5                 12.7         78.0
# 16  2016-06-01 16:00:00       16.5                 12.9         79.0
# 17  2016-06-01 17:00:00       16.5                 12.7         78.0
# 18  2016-06-01 18:00:00       15.6                 14.0         90.0
# 19  2016-06-01 19:00:00       15.2                 13.8         91.0
# 20  2016-06-01 20:00:00       14.8                 13.7         93.0
# 21  2016-06-01 21:00:00       14.3                 13.4         94.0
# 22  2016-06-01 22:00:00       14.1                 13.3         95.0
# 23  2016-06-01 23:00:00       14.2                 13.6         96.0
# 24  2016-06-02 00:00:00       14.2                 13.6         96.0
# 25  2016-06-02 01:00:00       14.4                 13.5         94.0
# 26  2016-06-02 02:00:00       14.4                 13.0         91.0
# 28                 12.0              8.0             24.1           101.21
# 29                 13.0              9.0             24.1           101.26
# ..                  ...              ...              ...              ...
# 690                14.0             18.0             48.3           101.83
# 691                14.0             17.0             48.3           101.83
# 692                13.0             23.0             48.3           101.86
# 693                11.0             25.0             48.3           101.90
# 694                13.0             22.0             48.3           101.91
# 695                13.0             19.0             48.3           101.95
# 696                11.0             18.0             48.3           101.96
# 697                10.0             13.0             48.3           102.01
# 698                10.0             16.0             48.3           102.04
# 699                 8.0             18.0             48.3           102.06
# 700                 8.0             14.0             32.2           102.12
# 701                 9.0             17.0             32.2           102.15
# 702                11.0             17.0             32.2           102.17
# 703                12.0             14.0             32.2           102.21
# 704                11.0             13.0             32.2           102.23
# 705                11.0             13.0             32.2           102.25
# 706                13.0             11.0             32.2           102.24
# 707                19.0              9.0             32.2           102.23
# 708                26.0              9.0             48.3           102.19
# 709                23.0             23.0             48.3           102.15
# 710                23.0             20.0             48.3           102.10
# 711                22.0             20.0             48.3           102.06
# 712                17.0             13.0             48.3           102.00
# 713                21.0             16.0             48.3           101.95
# 714                18.0             10.0             48.3           101.92
# 715                14.0             16.0             48.3           101.89
# 716                13.0             14.0             48.3           101.87
# 717                11.0             17.0             48.3           101.90
# 718                13.0             16.0             48.3           101.88
# 719                11.0             18.0             48.3           101.86
#
#            Weather
# 0              NaN
# 1           Cloudy
# 2              NaN
# 3              NaN
# 4    Mostly Cloudy
# 5              NaN
# 6              NaN
# 7    Mostly Cloudy
# 8              NaN
# 9              NaN
# 10          Cloudy
# 11             NaN
# 12             NaN
# 13          Cloudy
# 14            Rain
# 15            Rain
# 16            Rain
# 17             NaN
# 18             NaN
# 19          Cloudy
# 20            Rain
# 21            Rain
# 22            Rain
# 23            Rain
# 24             NaN
# 25            Rain
# 26             NaN
# 27            Rain
# 28          Cloudy
# 29             NaN
# ..             ...
# 690            NaN
# 691          Clear
# 692            NaN
# 693            NaN
# 694   Mainly Clear
# 695            NaN
# 696            NaN
# 697          Clear
# 698            NaN
# 699            NaN
# 700  Mostly Cloudy
# 701            NaN
# 702            NaN
# 703  Mostly Cloudy
# 704            NaN
# 705            NaN
# 706  Mostly Cloudy
# 707            NaN
# 708            NaN
# 709         Cloudy
# 710            NaN
# 711            NaN
# 712  Mostly Cloudy
# 713            NaN
# 714            NaN
# 715  Mostly Cloudy
# 716            NaN
# 717            NaN
# 718   Mainly Clear
# 719            NaN
#
# [720 rows x 9 columns]

# %%
test = weather_data[weather_data["Weather"].isnull()]
train = weather_data[~weather_data["Weather"].isnull()]

times = list(train['Date/Time'].map(lambda x: x))
test_times = list(test['Date/Time'].map(lambda x: x))

X_img_train = image_data[image_data.timestamp.isin(times)]
X_img_test = image_data[image_data.timestamp.isin(test_times)]

# times = list(X_img_train[X_img_train.timestamp.map(lambda x : x)])
# test_times = list(X_img_test[X_img_test.timestamp.map(lambda x : x)])


# X_train = weather_data[weather_data['Date/Time'].isin(times)]
# X_test = weather_data[weather_data['Date/Time'].isin(test_times)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-65-55056a7baa60> in <module>()
#       8 X_img_test = image_data[image_data.timestamp.isin(test_times)]
#       9
# ---> 10 times = list(X_img_train[X_img_train.timestamp.map(lambda x : x)])
#      11 test_times = list(X_img_test[X_img_test.timestamp.map(lambda x : x)])
#      12
#
# /home/seleena/.local/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    
00.000000000'\n '2016-06-18T08:00:00.000000000' '2016-06-18T09:00:00.000000000'\n '2016-06-18T10:00:00.000000000' '2016-06-18T11:00:00.000000000'\n '2016-06-18T12:00:00.000000000' '2016-06-18T13:00:00.000000000'\n '2016-06-18T14:00:00.000000000' '2016-06-18T15:00:00.000000000'\n '2016-06-18T16:00:00.000000000' '2016-06-18T17:00:00.000000000'\n '2016-06-18T19:00:00.000000000' '2016-06-18T21:00:00.000000000'\n '2016-06-19T06:00:00.000000000' '2016-06-19T07:00:00.000000000'\n '2016-06-19T10:00:00.000000000' '2016-06-19T13:00:00.000000000'\n '2016-06-19T16:00:00.000000000' '2016-06-19T19:00:00.000000000'\n '2016-06-20T07:00:00.000000000' '2016-06-20T10:00:00.000000000'\n '2016-06-20T13:00:00.000000000' '2016-06-20T16:00:00.000000000'\n '2016-06-20T19:00:00.000000000' '2016-06-21T07:00:00.000000000'\n '2016-06-21T10:00:00.000000000' '2016-06-21T13:00:00.000000000'\n '2016-06-21T16:00:00.000000000' '2016-06-21T19:00:00.000000000'\n '2016-06-22T07:00:00.000000000' '2016-06-22T10:00:00.000000000'\n '2016-06-22T13:00:00.000000000' '2016-06-22T16:00:00.000000000'\n '2016-06-22T17:00:00.000000000' '2016-06-22T19:00:00.000000000'\n '2016-06-22T20:00:00.000000000' '2016-06-22T21:00:00.000000000'\n '2016-06-23T06:00:00.000000000' '2016-06-23T07:00:00.000000000'\n '2016-06-23T08:00:00.000000000' '2016-06-23T09:00:00.000000000'\n '2016-06-23T10:00:00.000000000' '2016-06-23T13:00:00.000000000'\n '2016-06-23T16:00:00.000000000' '2016-06-23T19:00:00.000000000'\n '2016-06-24T07:00:00.000000000' '2016-06-24T10:00:00.000000000'\n '2016-06-24T13:00:00.0000000 ...

# %%
# reshape to (153,49152)
images = np.zeros((153,49152), dtype=np.float32)
for i in range(153):
    images[i] = X_img_train.image.iloc[0]

# %%
train.Weather.shape
# Out:
# (278,)

# %%
from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier(n_neighbors=5)
model.fit(images, train.Weather)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-a9125210c566> in <module>()
#       4
#       5 model = KNeighborsClassifier(n_neighbors=5)
# ----> 6 model.fit(images, train.Weather)
#
# /home/seleena/.local/lib/python3.5/site-packages/sklearn/neighbors/base.py in fit(self, X, y)
#     759         """
#     760         if not isinstance(X, (KDTree, BallTree)):
# --> 761             X, y = check_X_y(X, y, "csr", multi_output=True)
#     762
#     763         if y.ndim == 1 or y.ndim == 2 and y.shape[1] == 1:
#
# /home/seleena/.local/lib/python3.5/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     529         y = y.astype(np.float64)
#     530
# --> 531     check_consistent_length(X, y)
#     532
#     533     return X, y
#
# /home/seleena/.local/lib/python3.5/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     179     if len(uniques) > 1:
#     180         raise ValueError("Found input variables with inconsistent numbers of"
# --> 181                          " samples: %r" % [int(l) for l in lengths])
#     182
#     183
#
# ValueError: Found input variables with inconsistent numbers of samples: [153, 278]

# %% [markdown]
# ### Notes
# - try black and white images
# - try rgb images
# - try other color coding images
# - https://datascience.stackexchange.com/questions/5224/how-to-prepare-augment-images-for-neural-network
# - use temp, dew point, ... etc to estimate weather conditions
#
# Try:
# 1. remove nan data -> use for testing
# 2. impute nan weather data -> compare to #1
